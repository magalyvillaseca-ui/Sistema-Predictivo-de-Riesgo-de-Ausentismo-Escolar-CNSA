# %%
import pandas as pd

# %%
df = pd.read_csv('/content/asistencia_consolidada.csv')
#Mostrar las primeras 5 filas
display(df.head())
# Out:
#           curso  asistentes [01-04-2025]  inasistentes [01-04-2025]  \
# 0       COLEGIO                   1322.0                       95.0
# 1  Pre-Kinder A                     32.0                        5.0
# 2  Pre-Kinder B                     31.0                        8.0
# 3      Kinder A                     41.0                        8.0
# 4      Kinder B                     39.0                       11.0
#
#    asistentes [01-08-2025]  inasistentes [01-08-2025]  \
# 0                   1183.0                      233.0
# 1                     27.0                        8.0
# 2                     29.0                        6.0
# 3                     37.0                        9.0
# 4                     35.0                        9.0
#
#    asistentes [01-09-2025]  inasistentes [01-09-2025]  \
# 0                   1282.0                      132.0
# 1                     30.0                        5.0
# 2                     32.0                        6.0
# ...

# %%
#Ver tamaño de la matriz
print(f"\nDimensiones: {df.shape}")
# Out:
# Dimensiones: (34, 337)

# %% [markdown]
# Primera columna corresponde a "curso", se individualizan 33 cursos en dicha matriz, las siguientes columnas corresponden a las asistencias y inasistencias diarias y entre parentesis aparece al dia del año en que corresponde, son todos numeros enteros positivos, se necesitara hacer un tratamiento de los datos para poder utilizarlos.
